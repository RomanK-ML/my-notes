# %% [markdown]
# # Регулризация

# %% [markdown]
# Регуляризация - это способ борьбы с таким явлением как "переобучение".
#
# Пример оверфиттинга проще всего привести в виде картинки. Пусть вы решаете задачу классификации на два класса ( о которой уже знаете с первых уроков этого курса)
# * сначала модель, которая обучена не совсем хорошо (underfit) - разделяющая линия прямая и много "красных" точек неправильно классифицированы
# * затем хорошо обученная модель (normal) - есть какой-то баланс
# * переобученная модель (overfit) - разделяющая линия слишком сильно "облизывает" обучающие данные.
#
# ![overfit_example](https://248006.selcdn.ru/public/Data-science-3/img/overfit_example.png)
#
# Чем же плохо переобучение? Когда в модель придут "новые" точки, то качество модели будет низким, потому что модель слишком сильно подогналась под обучающие данные. В этом случае говорят, что падает "обобщающая способность" - модель не получается обощить на новые данные.

# %% [markdown]
# **Как бороться с переобучением линейной регрессии?** Нам надо как-то "наказать" модель за то, что она слишком сильно подгоняется под обучающую выборку. Это можно сделать помощью регуляризации! Регуляризация - это специальная модификация модели линейной регрессии. В стандартной библиотеки sklearn есть два класса, в которых реализована регуляризация:
# * sklearn.linear_model.Ridge, ссылка на доку https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html
# * sklearn.linear_model.Lasso, ссылка на доку https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html
#
# Чем отличаются эти два класса мы узнаем в следующих уроках этого модуля. Мы уже знакомы с классом `sklearn.linear_model.LinearRegression`, с который вообще не требует никаких параметров при создании, а вот классы `Ridge` и `Lasso` принимают на вход т.н. параметр регуляризации *alpha*, который принимает значения от $0$ до $1$ - чем ближе к единице, тем регуляризация сильнее, тем сильнее наказываем модель за сильную "подгонку" под обучающие данные.

# %% [markdown]
# ## Формулы

# %% [markdown]
# Как регуляризация появляется в формулах?
#
# Мы уже умеем определять, что модель переобучилась - нужно обучать на тренировочном сете, а метрику качества считать на валидационном.

# %%
import matplotlib.pyplot as plt

# основной график
plt.scatter(data.x_train, data.y_train, 40, 'g', 'o', alpha=0.8)
plt.show()

# %% [markdown]
# Обучим полиномиальную регрессию для разных степеней полинома. Мы уже знаем, что для полиномиальной модели порядка $n$ в матрицу фичей $X$ добавляются степени фичей (например, в случае обучения регрессии на единственной фиче модуль приобретёт вид $y = w_0 + w_1x +w_2x^2 + \ldots + w_nx^n$).
#
# Кроме прочей информации будем вычислять т.н. *норму вектора* - это просто корень из суммы квадратов коэффициентов линейной регрессии. Чтобы избавиться от корня, будем вычислять квадрат нормы, обозначается как $\|w\|^2$.
#
# * https://www.youtube.com/watch?time_continue=1&v=b0dgsaYbOVI
# * https://www.youtube.com/watch?time_continue=262&v=05j0DOCRnjI
# * [Статья про норму вектора на википедии](https://ru.wikipedia.org/wiki/Норма_(математика))

# %% [markdown]
# Норма вектора обозначется двумя вертикальными линиями:
# $$
# \|w\|^2 = w_1^2+\ldots+w_n^2
# $$
#
# Для вычисления этой метрики используем [функцию norm из numpy](https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.linalg.norm.html).

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import norm
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


def generate_degrees(source_data: list, degree: int):
    """Функция, которая принимает на вход одномерный массив, а возвращает n-мерный
    Для каждой степени от 1 до  degree возводим x в эту степень
    """
    return np.array([
          source_data**n for n in range(1, degree + 1)  
    ]).T

def train_polynomial(degree, data):
    """Генерим данные, тренируем модель  
    дополнительно рисуем график
    """
    X = generate_degrees(data['x_train'], degree)
    y = data.y_train.values
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)
    model = LinearRegression().fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    y_pred_train = model.predict(X_train)
    error_valid = mean_squared_error(y_valid, y_pred)
    error_train = mean_squared_error(y_train, y_pred_train)
    print(
        "Степень полинома %d\nОшибка на валидации %.3f\nОшибка на обучении %.3f" %
        (degree, error_valid, error_train)
    )
    order_test = np.argsort(X_valid[:,0])
    plt.scatter(X_valid[:,0][order_test], y_valid[order_test], 40, 'r', 'o', alpha=0.8)
    print("Норма вектора весов \t||w|| = %.2f" % (norm(model.coef_)))
    # визуализируем решение
    x_linspace = np.linspace(data['x_train'].min(), data['x_train'].max(), num=100)
    y_linspace = model.predict(generate_degrees(x_linspace, degree))
    plt.plot(x_linspace, y_linspace)
    return error_valid, error_train, norm(model.coef_)

degrees = []
valid_errors = []
train_errors = []
w_norm = []

# %%
degree = 3

error_valid, error_train, coef_norm = train_polynomial(degree, data)

degrees.append(degree)
valid_errors.append(error_valid)
train_errors.append(error_train)
w_norm.append(coef_norm)
# Out:
# Степень полинома 3
# Ошибка на валидации 0.051
# Ошибка на обучении 0.077
# Норма вектора весов 	||w|| = 2.19

# %%
degree = 5

error_valid, error_train, coef_norm = train_polynomial(degree, data)

degrees.append(degree)
valid_errors.append(error_valid)
train_errors.append(error_train)
w_norm.append(coef_norm)
# Out:
# Степень полинома 5
# Ошибка на валидации 0.063
# Ошибка на обучении 0.069
# Норма вектора весов 	||w|| = 3.31

# %%
degree = 10

error_valid, error_train, coef_norm = train_polynomial(degree, data)

degrees.append(degree)
valid_errors.append(error_valid)
train_errors.append(error_train)
w_norm.append(coef_norm)
# Out:
# Степень полинома 10
# Ошибка на валидации 0.122
# Ошибка на обучении 0.052
# Норма вектора весов 	||w|| = 120.14

# %%
from matplotlib import pyplot
# %matplotlib inline

fig, ax = plt.subplots()
ax.plot(degrees, valid_errors, 'k--', label='Validation error')
ax.plot(degrees, train_errors, 'k:', label='Train error')

legend = ax.legend(loc='upper center', shadow=True, fontsize='x-large')

plt.show()

# %% [markdown]
# На графике можно заметить, как с ростом степени полинома ошибка на валидации начинает расти, а на обучении, наоборот, падать. Одновременно с ухудшением качества модели на валидации можно заметить, как растёт норма вектора коэффициентов $w$ -  от значения $2.19$ до значения $120.14$, то есть большие по модулю величины коэффициентов свидетельствуют о том, что модель переобучается.
#
# Мы хотели узнать, в какой точке модель будет получается сбалансированной и не "оверфиттится". Эта точка - там, где две линии ошибок пересекаются. В этой точке, которая соответствует степени полинома *degree=5*, модель достаточно хороша на обучении и не слишком плоха на валидации.

# %% [markdown]
# Мы подобрались к главному вопросу этого модуля: почему случается переобучение с точки зрения математики? Вспомним, что мы получаем предсказания модели, используя коэффициенты регрессии, в виде
#
# $$
# \hat{y} = w_0x_0 + \ldots w_nx_n
# $$
#
# По этой формуле видно, что величина коэффициентов $w$ по модулю сильно влияет на предсказания - чем больше коэффициенты линейной регрессии $w=[w_1,\ldots,w_n]$, тем больше таргет $y$ при одинаковом значении $x$, зависимость линейная.
#
# Вспомним, что аналитическая формула для нахождения коэффициентов регрессии выглядит вот так
# $$
# \overline{w} = \left(X^TX\right)^{-1}X^TY
# $$
#
# Такое решение получается, когда мы минимизируем функцию ошибок ($N$ - число обучающих примеров):
#
# $$
# L(y,w) = \sum_{i=1}^{N}\left(y_i - \hat{y_i}\right)^2
# $$
#
# В эксперименте с полиномиальной регрессией мы выяснили простое правило - чем больше квадраты коэффициентов регрессии, тем хуже качество. Как же нам заставить модель делать коэффициенты поменьше, чтобы качество не страдало?
#
# Самое простое решение, которое приходит на ум - каким-то образом "наказывать" нашу модель за слишком большие значения коэффициентов линейной регрессии $w$. Давайте добавим в функцию качества модели $L(y, w)$ дополнительное слагаемое, которое содержит квадрат нормы вектора весов $\|w\|^2$:
#
# $$
# L(y,w) = \sum_{i=1}^{N}\left(y_i - \hat{y_i}\right)^2 + \alpha \cdot \sum_{i=1}^{k}w_i^2 = \sum_{i=1}^{N}\left(y_i - \hat{y_i}\right)^2 + \alpha \cdot \|w\|^2
# $$
#
# С помощью этого трюка мы минимизируем функцию $L(x,w)$ как бы в двух направлениях:
# * уменьшаем ошибку $y-\hat{y}$ (первый компонент формулы)
# * следим за нормой коэффициентов регрессии $\|w\|^2$ - модель вынуждена делать коэффициенты как можно меньшими, потому что их размер влияет на функцию ошибки $L(x,w)$
#
# Эксперимент показал: чем больше $\|w\|^2$, тем сильнее переобучение. Следовательно, сделав коэффициенты более маленькими, мы уменьшим переобучение!

# %% [markdown]
# Такой процесс добавления слегаемых в целевую функцию называется *регуляризацией*. Регуляризация - это наложение дополнительных ограничений на целевую функцию $L(y, w)$. Добавляя в функцию качества $L$ сумму квадратов коэффициентов регрессии мы "принуждаем" нашу модель к тому, чтобы веса $w=[w_1,\ldots,w_k]$ были как можно более меньшими по модулю. Вернёмся к формуле целевой функции регуляризованной линейной регрессии:
# $$
# L(y,w) = \sum_{i=1}^{N}\left(y_i - \hat{y_i}\right)^2 + \alpha \cdot \|w\|^2
# $$
#
# В этой формуле
# * $\alpha$ - параметр регуляризации. Он принимает значения от $0$ до $1$: чем ближе к $1$ - тем сильнее регуляризация, тем сильнее уменьшаются веса линейной регрессии
# * квадрат нормы коэффициентов линейной регрессии: $\|w\|^2 = \sum_{i=1}^{k}w_i^2$

# %% [markdown]
# # Подготовка

# %% [markdown]
# ## Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Загрузка данных

# %%
data = pd.read_csv('non_linear.csv', sep=',')
data.head()
# Out:
#     x_train   y_train
# 0  0.138368  0.838812
# 1  0.157237  0.889313
# 2  0.188684  1.430040
# 3  0.685553  1.717309
# 4  0.874237  2.032588

# %% [markdown]
# # Ridge

# %%
def generate_degrees(source_data: list, degree: int):
    """Функция, которая принимает на вход одномерный массив, а возвращает n-мерный
    Для каждой степени от 1 до  degree возводим x в эту степень
    """
    return np.array([
          source_data**n for n in range(1, degree + 1)  
    ]).T

# %%
degree = 12
X = generate_degrees(data['x_train'], degree)
y = data.y_train.values
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)
model = Ridge(alpha=0).fit(X_train, y_train)
y_pred = model.predict(X_valid)
y_pred_train = model.predict(X_train)
print("Качество на валидации: %.3f" % mean_squared_error(y_valid, y_pred))
print("Качество на обучении: %.3f" % mean_squared_error(y_train, y_pred_train))
# Out:
# Качество на валидации: 0.125
# Качество на обучении: 0.051

# %%
degree = 12
X = generate_degrees(data['x_train'], degree)
y = data.y_train.values
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)
model = Ridge(alpha=0.01).fit(X_train, y_train)
y_pred = model.predict(X_valid)
y_pred_train = model.predict(X_train)
print("Качество на валидации: %.3f" % mean_squared_error(y_valid, y_pred))
print("Качество на обучении: %.3f" % mean_squared_error(y_train, y_pred_train))
# Out:
# Качество на валидации: 0.077
# Качество на обучении: 0.058
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.80566e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

degree = 12
X = generate_degrees(data['x_train'], degree)
y = data.y_train.values
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)

model = Lasso(alpha=0.01).fit(X_train, y_train)

y_pred_train = model.predict(X_train)
y_pred = model.predict(X_valid)

mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)

mae = mean_absolute_error(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
r2 = r2_score(y_valid, y_pred)

print("MAE на валидации: %.3f" % mae)
print("MAE на обучении: %.3f\n" % mae_train)
print("MSE на валидации: %.3f" % mse)
print("MSE на обучении: %.3f\n" % mse_train)
print("R2 на валидации: %.3f" % r2)
print("R2 на обучении: %.3f" % r2_train)
# Out:
# MAE на валидации: 0.196
# MAE на обучении: 0.239
#
# MSE на валидации: 0.063
# MSE на обучении: 0.086
#
# R2 на валидации: 0.915
# R2 на обучении: 0.859
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.392e+00, tolerance: 2.448e-03
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

degree = 12
X = generate_degrees(data['x_train'], degree)
y = data.y_train.values
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)

model = LassoCV(cv=5).fit(X_train, y_train)

y_pred_train = model.predict(X_train)
y_pred = model.predict(X_valid)

mae_train = mean_absolute_error(y_train, y_pred_train)
mse_train = mean_squared_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)

mae = mean_absolute_error(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
r2 = r2_score(y_valid, y_pred)

print("MAE на валидации: %.3f" % mae)
print("MAE на обучении: %.3f\n" % mae_train)
print("MSE на валидации: %.3f" % mse)
print("MSE на обучении: %.3f\n" % mse_train)
print("R2 на валидации: %.3f" % r2)
print("R2 на обучении: %.3f" % r2_train)
# Out:
# MAE на валидации: 0.574
# MAE на обучении: 0.579
#
# MSE на валидации: 0.501
# MSE на обучении: 0.475
#
# R2 на валидации: 0.323
# R2 на обучении: 0.224
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003491819816066055, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00602819479609451, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00708945913883241, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007627481847546136, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007956548104225192, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008171170105015335, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008305626147585343, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008377467236300618, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008398766566280358, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008379096133612762, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008326418058743457, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008247441298273372, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008147829132411744, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00803235410780978, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007905026096342027, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007769201543458948, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007627677533774246, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007482772882516642, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007336398135013411, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007190115886290371, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0070451928161858746, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006902644418975257, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006763273542564008, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006627703519928474, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006496406580508207, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0063697282725101445, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006247908307232208, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006131098499896126, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006019377993805364, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005912766308668438, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005811234445985747, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0057147142602111956, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005623106518783061, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00553628758530067, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005454115133378679, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005376432944480314, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005303074859417833, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0052338681898778106, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005168636369347723, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005107201302879005, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005049385251288285, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004995012159417556, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004943909131341684, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004895907129213839, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00485084187731033, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004808554285720135, tolerance: 0.001901160628308103
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002278264483141612, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004540830303167098, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0054749031358802824, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005974284406903507, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006300197517465023, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0065232424580123904, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00666947771906834, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006753903968714781, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006787817480194747, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006780534583263886, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006739914799545943, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006672613992813936, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006584262783594141, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006479612647364519, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006362660642583506, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006236756878182703, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006104697312689922, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0059688038650218544, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005830993584392985, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005692838253846588, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005555615843945816, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005420354762726731, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005287871956568324, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005158805691369395, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005033643699713153, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004912747311221821, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004796372180621233, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0046846859635980564, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004577783525483881, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0044756997684824995, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004378420758538226, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004285892982192507, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004198031334581742, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004114725809559516, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004035847202628062, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00396125183795526, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003890785565648258, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0038242871070686135, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037615908722372637, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037025290638101893, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003646933728184365, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003594638227745861, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003545478355931664, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00349929348437783, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0034559271473124653, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003415227691178302, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003377048683219641, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0033412492897806345, tolerance: 0.0020897200021314215
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003022731503978804, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0043559217882069845, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0049183154706504695, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005232651305005831, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005439006560253645, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005577405851804329, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005664116305574396, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005709133133972699, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005720146594416775, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005703526614743382, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0056646475131145735, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005608056593237265, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005537596259898692, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005456504635624526, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005367501522009377, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0052728624727045315, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005174482729605856, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005073932414990878, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004972504171259828, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004871254190671692, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004771037626122521, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004672539050295299, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004576298654509259, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004482734782040865, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00439216326492442, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004304814029913118, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004220845270671347, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004140355641100157, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004063394624601813, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00398997136060153, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003920062239780364, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003853617227182582, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037905653597540834, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037308192684175623, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0036742790867307917, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0036208356328391034, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0035703731898202307, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0035227717267449776, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0034779087671150677, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0034356609133201488, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0033959051116010386, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0033585196993684008, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003323385179553995, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003290384822738801, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0032594052961947284, tolerance: 0.0017397884126073274
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003377142972855296, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008584994806460244, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01108699263786228, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012293301496136166, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012956835050246696, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013355038476097647, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0135918972913327, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013713469729195182, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013745827637679398, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013707152983950976, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013611685142301155, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013471132965088728, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008900135934704068, tolerance: 0.0020445416880279133
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0035417612218573424, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005298569285816512, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006102186714400659, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00657547126598601, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006893112508755905, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007108189273132837, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007243993368534873, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007315558426112645, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0073346566045469075, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007311086292283164, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007253125078314326, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007167779651306105, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007060971769199398, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006937692745001556, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006802135695355815, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006657809550597804, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006507637486372175, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006354041902135066, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006199017728555134, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006044195660484419, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005890896629807685, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005740178714820132, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005592877490322223, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005449640738254047, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005310958193570414, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00517718714872295, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005048574267185302, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00492527435627288, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004807366350272346, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0046948669329012205, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0045877421653433, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004485917328469924, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004389285304469581, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004297713624854538, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004211050378291503, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004129129302780754, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004051773892653543, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003978800885457545, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003910023189849454, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0038452521834297926, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037842997358499275, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037269796951964196, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003673109189826107, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003622509665559548, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0035750074243789953, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003530434555676365, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003488629065202531, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0034494352528717798, tolerance: 0.0019916752121011427
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/roman/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.622e+00, tolerance: 2.448e-03
#   model = cd_fast.enet_coordinate_descent(
