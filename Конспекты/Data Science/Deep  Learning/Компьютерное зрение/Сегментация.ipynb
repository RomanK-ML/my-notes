# %%
import numpy  as np
import pandas as pd
import random
import imageio
import matplotlib.pyplot as plt
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# # Реализация обучения FCN
# В этом модуле мы создадим нашу первую FCN модель для задачи Семантической Сегментации. А также построим пайплайн обучения этой модели.
#
# Обучение такой модели на реальных данных займет достаточно длительное время. Поэтому мы будем обучаться на очень маленьком датасете, состоящем из одной картинки (и её зеркальной копии). При таком подходе мы столкнемся с проблемой переобучения ("запоминание" обучающей выборки и отсутствие обобщения), но ничего страшного. Нам лишь нужно будет протестировать, что пайплайн и модель работают корректно.

# %% [markdown]
# ## Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.v2.imread('img/me_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон
# То же самое касается файла 'me_gt_256.png'.
#
# После загрузки мы приводим 3 канала RGB к одному каналу путём усреднения.
#
# Это наша Ground-Truth карта сегментации, размеченная кем-то (мною) вручную.
# Значение `'0'` в ней означает класс "фон", значение `'1'` -- класс "человек"

# %%
gt = imageio.v2.imread('img/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать и протестировать пайплайн для обучения FCN модели, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты эксперимента возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# Индексирование `'::-1'` означает взять все элементы в обратном порядке.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались.

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1d38b395300>, None)

# %% [markdown]
# ## Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
# Модель создаётся путём наслелования от `tf.keras.Model`.
#
# В методе `Model.__init__` создаются слои.
#
# В методе `Model.call` производится инференс с использованием созданных слоёв и других функций TensorFlow

# %%
NUM_EPOCHS = 100

class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation=None)
        self.pool = tf.keras.layers.MaxPool2D((2, 2))

    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.pool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.pool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out = tf.image.resize(out, (x.shape[1], x.shape[2]), tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out

model = Model()

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 456ms/step - loss: 0.6820
# Epoch 2/100
# 2/2 [==============================] - 1s 456ms/step - loss: 0.6454
# Epoch 3/100
# 2/2 [==============================] - 1s 435ms/step - loss: 0.5621
# Epoch 4/100
# 2/2 [==============================] - 1s 440ms/step - loss: 0.3675
# Epoch 5/100
# 2/2 [==============================] - 1s 408ms/step - loss: 0.2615
# Epoch 6/100
# 2/2 [==============================] - 1s 393ms/step - loss: 0.2346
# Epoch 7/100
# 2/2 [==============================] - 1s 637ms/step - loss: 0.2053
# Epoch 8/100
# 2/2 [==============================] - 1s 663ms/step - loss: 0.2188
# Epoch 9/100
# 2/2 [==============================] - 1s 610ms/step - loss: 0.2178
# Epoch 10/100
# 2/2 [==============================] - 1s 537ms/step - loss: 0.2059
# Epoch 11/100
# 2/2 [==============================] - 1s 472ms/step - loss: 0.2056
# Epoch 12/100
# 2/2 [==============================] - 1s 548ms/step - loss: 0.2062
# Epoch 13/100
# 2/2 [==============================] - 1s 520ms/step - loss: 0.2023
# Epoch 14/100
# 2/2 [==============================] - 1s 631ms/step - loss: 0.1967
# Epoch 15/100
# 2/2 [==============================] - 1s 626ms/step - loss: 0.1921
# Epoch 16/100
# 2/2 [==============================] - 1s 431ms/step - loss: 0.1877
# Epoch 17/100
# 2/2 [==============================] - 1s 433ms/step - loss: 0.1804
# Epoch 18/100
# 2/2 [==============================] - 1s 461ms/step - loss: 0.1732
# Epoch 19/100
# 2/2 [==============================] - 1s 594ms/step - loss: 0.1633
# Epoch 20/100
# 2/2 [==============================] - 1s 482ms/step - loss: 0.1308
# Epoch 21/100
# 2/2 [==============================] - 1s 468ms/step - loss: 0.1670
# Epoch 22/100
# 2/2 [==============================] - 1s 456ms/step - loss: 0.2460
# Epoch 23/100
# 2/2 [==============================] - 1s 470ms/step - loss: 0.4775
# Epoch 24/100
# 2/2 [==============================] - 1s 490ms/step - loss: 0.3562
# Epoch 25/100
# 2/2 [==============================] - 2s 694ms/step - loss: 0.1987
# Epoch 26/100
# 2/2 [==============================] - 1s 497ms/step - loss: 0.2467
# Epoch 27/100
# 2/2 [==============================] - 1s 532ms/step - loss: 0.2266
# Epoch 28/100
# 2/2 [==============================] - 1s 525ms/step - loss: 0.2031
# Epoch 29/100
# 2/2 [==============================] - 1s 705ms/step - loss: 0.1969
# Epoch 30/100
# 2/2 [==============================] - 1s 439ms/step - loss: 0.1977
# Epoch 31/100
# 2/2 [==============================] - 2s 816ms/step - loss: 0.1967
# Epoch 32/100
# 2/2 [==============================] - 1s 570ms/step - loss: 0.1915
# Epoch 33/100
# 2/2 [==============================] - 1s 615ms/step - loss: 0.1854
# Epoch 34/100
# 2/2 [==============================] - 1s 491ms/step - loss: 0.1818
# Epoch 35/100
# 2/2 [==============================] - 1s 572ms/step - loss: 0.1813
# Epoch 36/100
# 2/2 [==============================] - 1s 572ms/step - loss: 0.1790
# Epoch 37/100
# 2/2 [==============================] - 1s 503ms/step - loss: 0.1745
# Epoch 38/100
# 2/2 [==============================] - 1s 543ms/step - loss: 0.1703
# Epoch 39/100
# 2/2 [==============================] - 1s 552ms/step - loss: 0.1658
# Epoch 40/100
# 2/2 [==============================] - 1s 482ms/step - loss: 0.1605
# Epoch 41/100
# 2/2 [==============================] - 1s 517ms/step - loss: 0.1513
# Epoch 42/100
# 2/2 [==============================] - 1s 663ms/step - loss: 0.1394
# Epoch 43/100
# 2/2 [==============================] - 1s 520ms/step - loss: 0.1242
# Epoch 44/100
# 2/2 [==============================] - 1s 584ms/step - loss: 0.1146
# Epoch 45/100
# 2/2 [==============================] - 1s 521ms/step - loss: 0.1032
# Epoch 46/100
# 2/2 [==============================] - 1s 611ms/step - loss: 0.0875
# Epoch 47/100
# 2/2 [==============================] - 1s 781ms/step - loss: 0.0752
# Epoch 48/100
# 2/2 [==============================] - 1s 463ms/step - loss: 0.0653
# Epoch 49/100
# 2/2 [==============================] - 1s 735ms/step - loss: 0.0581
# Epoch 50/100
# 2/2 [==============================] - 1s 690ms/step - loss: 0.0531
# Epoch 51/100
# 2/2 [==============================] - 1s 626ms/step - loss: 0.0463
# Epoch 52/100
# 2/2 [==============================] - 1s 627ms/step - loss: 0.0395
# Epoch 53/100
# 2/2 [==============================] - 1s 799ms/step - loss: 0.0358
# Epoch 54/100
# 2/2 [==============================] - 1s 555ms/step - loss: 0.0314
# Epoch 55/100
# 2/2 [==============================] - 1s 679ms/step - loss: 0.0288
# Epoch 56/100
# 2/2 [==============================] - 1s 614ms/step - loss: 0.0281
# Epoch 57/100
# 2/2 [==============================] - 1s 411ms/step - loss: 0.0268
# Epoch 58/100
# 2/2 [==============================] - 1s 444ms/step - loss: 0.0253
# Epoch 59/100
# 2/2 [==============================] - 1s 438ms/step - loss: 0.0262
# Epoch 60/100
# 2/2 [==============================] - 1s 821ms/step - loss: 0.0253
# Epoch 61/100
# 2/2 [==============================] - 1s 594ms/step - loss: 0.0243
# Epoch 62/100
# 2/2 [==============================] - 1s 669ms/step - loss: 0.0223
# Epoch 63/100
# 2/2 [==============================] - 1s 495ms/step - loss: 0.0223
# Epoch 64/100
# 2/2 [==============================] - 1s 691ms/step - loss: 0.0203
# Epoch 65/100
# 2/2 [==============================] - 1s 473ms/step - loss: 0.0190
# Epoch 66/100
# 2/2 [==============================] - 1s 493ms/step - loss: 0.0185
# Epoch 67/100
# 2/2 [==============================] - 1s 424ms/step - loss: 0.0174
# Epoch 68/100
# 2/2 [==============================] - 1s 402ms/step - loss: 0.0165
# Epoch 69/100
# 2/2 [==============================] - 1s 552ms/step - loss: 0.0157
# Epoch 70/100
# 2/2 [==============================] - 1s 437ms/step - loss: 0.0153
# Epoch 71/100
# 2/2 [==============================] - 1s 604ms/step - loss: 0.0148
# Epoch 72/100
# 2/2 [==============================] - 1s 613ms/step - loss: 0.0143
# Epoch 73/100
# 2/2 [==============================] - 1s 618ms/step - loss: 0.0138
# Epoch 74/100
# 2/2 [==============================] - 1s 432ms/step - loss: 0.0136
# Epoch 75/100
# 2/2 [==============================] - 1s 531ms/step - loss: 0.0127
# Epoch 76/100
# 2/2 [==============================] - 1s 399ms/step - loss: 0.0123
# Epoch 77/100
# 2/2 [==============================] - 1s 480ms/step - loss: 0.0123
# Epoch 78/100
# 2/2 [==============================] - 1s 531ms/step - loss: 0.0113
# Epoch 79/100
# 2/2 [==============================] - 1s 409ms/step - loss: 0.0109
# Epoch 80/100
# 2/2 [==============================] - 1s 403ms/step - loss: 0.0106
# Epoch 81/100
# 2/2 [==============================] - 1s 583ms/step - loss: 0.0102
# Epoch 82/100
# 2/2 [==============================] - 1s 471ms/step - loss: 0.0101
# Epoch 83/100
# 2/2 [==============================] - 1s 449ms/step - loss: 0.0098
# Epoch 84/100
# 2/2 [==============================] - 1s 491ms/step - loss: 0.0100
# Epoch 85/100
# 2/2 [==============================] - 1s 432ms/step - loss: 0.0092
# Epoch 86/100
# 2/2 [==============================] - 1s 380ms/step - loss: 0.0097
# Epoch 87/100
# 2/2 [==============================] - 1s 385ms/step - loss: 0.0097
# Epoch 88/100
# 2/2 [==============================] - 1s 420ms/step - loss: 0.0085
# Epoch 89/100
# 2/2 [==============================] - 1s 465ms/step - loss: 0.0082
# Epoch 90/100
# 2/2 [==============================] - 1s 409ms/step - loss: 0.0080
# Epoch 91/100
# 2/2 [==============================] - 1s 477ms/step - loss: 0.0079
# Epoch 92/100
# 2/2 [==============================] - 1s 431ms/step - loss: 0.0076
# Epoch 93/100
# 2/2 [==============================] - 1s 436ms/step - loss: 0.0077
# Epoch 94/100
# 2/2 [==============================] - 1s 432ms/step - loss: 0.0090
# Epoch 95/100
# 2/2 [==============================] - 1s 473ms/step - loss: 0.0076
# Epoch 96/100
# 2/2 [==============================] - 1s 456ms/step - loss: 0.0073
# Epoch 97/100
# 2/2 [==============================] - 1s 423ms/step - loss: 0.0074
# Epoch 98/100
# 2/2 [==============================] - 1s 437ms/step - loss: 0.0071
# Epoch 99/100
# 2/2 [==============================] - 1s 486ms/step - loss: 0.0068
# Epoch 100/100
# 2/2 [==============================] - 1s 436ms/step - loss: 0.0067

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])
# Out:
# 1/1 [==============================] - 0s 179ms/step

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step

# %% [markdown]
# # Реализация модернизированной FCN сети

# %% [markdown]
# ## Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.v3.imread('img/me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон

# %%
gt = imageio.v3.imread('img/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать пайплайн для обучения, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1c97fb5d4b0>, None)

# %% [markdown]
# ## Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
#
# Для создания модели создадим собственный класс, наследованный от tf.keras.Model. Ранее мы использовали лишь свёртки и пулинги для извлечения признаков и понижения пространственных размерностий. Это был наш Энкодер.
# В качестве Декодера у нас был простой Upscale слой, который просто расширял изображение до нужного размера. Теперь же давайте реализуем более качественный Декодер с использованием слоёв для повышения разрешения.
#
# В примере ниже будем использовать Unpooling (в керасе это делает слой tf.keras.layers.UpSampling2D) перемежающиийся со свёрточными слоями.
#
# Для понижения размерности используются свёртки со страйдом. Для повышения размерности - Unpooling (nearest neighbour)
#
# Модель создаётся путём наслелования от `tf.keras.Model`.
#
# В методе `Model.__init__` создаются слои.
#
# В методе `Model.call` производится инференс с использованием созданных слоёв и других функций TensorFlow

# %%
class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')

        self.conv3 = tf.keras.layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='relu')

        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')

        self.conv6 = tf.keras.layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu')

        self.conv7 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv8 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')

        self.conv9 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv10 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')

        self.conv11 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv12 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')

        self.unpool = tf.keras.layers.UpSampling2D((2, 2))

    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)

        out = self.conv4(out)
        out = self.conv5(out)
        out = self.conv6(out)

        out = self.conv7(out)
        out = self.conv8(out)
        out = self.unpool(out)

        out = self.conv9(out)
        out = self.conv10(out)
        out = self.unpool(out)

        out = self.conv11(out)
        out = self.conv12(out)

        return out

model = Model()

# %% [markdown]
# ### Параметры обучения

# %%
NUM_EPOCHS = 100

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6896
# Epoch 2/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6712
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6430
# Epoch 4/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.4373
# Epoch 5/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3083
# Epoch 6/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.3156
# Epoch 7/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2811
# Epoch 8/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2378
# Epoch 9/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.2363
# Epoch 10/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.2183
# Epoch 11/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2012
# Epoch 12/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1872
# Epoch 13/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1824
# Epoch 14/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1952
# Epoch 15/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1177
# Epoch 16/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1472
# Epoch 17/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1615
# Epoch 18/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1685
# Epoch 19/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1319
# Epoch 20/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1216
# Epoch 21/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0990
# Epoch 22/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0575
# Epoch 23/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0469
# Epoch 24/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7705
# Epoch 25/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.3848
# Epoch 26/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2080
# Epoch 27/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2240
# Epoch 28/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.2552
# Epoch 29/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.2105
# Epoch 30/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2055
# Epoch 31/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2047
# Epoch 32/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1743
# Epoch 33/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1557
# Epoch 34/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1556
# Epoch 35/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1443
# Epoch 36/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1332
# Epoch 37/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.1073
# Epoch 38/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0757
# Epoch 39/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0727
# Epoch 40/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0616
# Epoch 41/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1012
# Epoch 42/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0346
# Epoch 43/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0536
# Epoch 44/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0923
# Epoch 45/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0589
# Epoch 46/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0693
# Epoch 47/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.0363
# Epoch 48/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0475
# Epoch 49/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0296
# Epoch 50/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0342
# Epoch 51/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0296
# Epoch 52/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0324
# Epoch 53/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.0241
# Epoch 54/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0276
# Epoch 55/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0207
# Epoch 56/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0228
# Epoch 57/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0207
# Epoch 58/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0200
# Epoch 59/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0203
# Epoch 60/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0176
# Epoch 61/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0182
# Epoch 62/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0168
# Epoch 63/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0163
# Epoch 64/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0154
# Epoch 65/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0150
# Epoch 66/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0141
# Epoch 67/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0139
# Epoch 68/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0130
# Epoch 69/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0127
# Epoch 70/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0122
# Epoch 71/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0115
# Epoch 72/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0111
# Epoch 73/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0107
# Epoch 74/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0102
# Epoch 75/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0097
# Epoch 76/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0092
# Epoch 77/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0088
# Epoch 78/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0082
# Epoch 79/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0080
# Epoch 80/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0074
# Epoch 81/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0072
# Epoch 82/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0067
# Epoch 83/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0064
# Epoch 84/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0071
# Epoch 85/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0067
# Epoch 86/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0062
# Epoch 87/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0060
# Epoch 88/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0059
# Epoch 89/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0067
# Epoch 90/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0058
# Epoch 91/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0059
# Epoch 92/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0058
# Epoch 93/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0056
# Epoch 94/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0056
# Epoch 95/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0053
# Epoch 96/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.0051
# Epoch 97/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0050
# Epoch 98/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0050
# Epoch 99/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0048
# Epoch 100/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0047

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])
# Out:
# 1/1 [==============================] - 0s 369ms/step

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 358ms/step

# %% [markdown]
# # Реализация FCN сети на основе архитектуры UNet
#
# Мы создадим еще более качественную FCN модель на основе архитектуры UNet. Кроме использовавшихся ранее слоёв, здесь также будут участвовать Skipped Connections (проброшенные связи).
#
#
# <img src="img/unet.jpg" width="1000">

# %% [markdown]
# ## Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.v3.imread('img/me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон

# %%
gt = imageio.v3.imread('img/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать пайплайн для обучения, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x27a23a8f970>, None)

# %% [markdown]
# ## Пайплайн обучения UNet

# %% [markdown]
# ### Создание UNet модели
# Так как UNet имееет разветвления, мы не сможем создать её с помощью `tf.keras.Sequential`. Остаётся либо создать свой собственный класс, либо использовать функциональный API. Так как граф у нас будет статический (без каких-то условных ветвлений), и нам потом желательно визуализировать полученный граф, чтобы проверить, что мы всё соединили правильно, мы будем использовать именно функциональный API.
#
# В архитектуре UNet для понижения размерности используется MaxPooling, а для повышения -- Conv2DTranspose (Транспонированная свёртка, Upconv). Кроме того, присутствуют проброшенные связи (skipped connections): некоторые тензоры из Энкодера конкатенируются по канальному измерению (axis=3) с тензорами из Декодера. В остальном эта модель очень похожа на обычную Encoder-Decoder нейросеть из предыдущего практического урока.
#
# В отличие от классической UNet архитектуры, мы во всех слоях будем использовать `padding='same'`, чтобы избавиться от необходимости делать crop при конкатинации тензоров из разных участков сети.

# %%
def build_model():
    x = tf.keras.layers.Input((256, 256, 3))

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    out1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', strides=(2, 2), activation='relu')(out1)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out2 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', strides=(2, 2), activation='relu')(out2)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out3 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', strides=(2, 2), activation='relu')(out3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out4 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', strides=(2, 2), activation='relu')(out4)

    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out4, out], axis=3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out3, out], axis=3)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out2, out], axis=3)

    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out1, out], axis=3)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')(out)

    return tf.keras.Model(inputs=x, outputs=out)

model = build_model()

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### Параметры обучения

# %%
NUM_EPOCHS = 100

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0801
# Epoch 2/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0759
# Epoch 3/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0703
# Epoch 4/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0662
# Epoch 5/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0623
# Epoch 6/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0590
# Epoch 7/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0565
# Epoch 8/100
# 2/2 [==============================] - 10s 6s/step - loss: 0.0529
# Epoch 9/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0510
# Epoch 10/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0487
# Epoch 11/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.0477
# Epoch 12/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0438
# Epoch 13/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0433
# Epoch 14/100
# 2/2 [==============================] - 8s 3s/step - loss: 0.0411
# Epoch 15/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0393
# Epoch 16/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0371
# Epoch 17/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0363
# Epoch 18/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1801
# Epoch 19/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.2392
# Epoch 20/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.3449
# Epoch 21/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.3637
# Epoch 22/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1753
# Epoch 23/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1436
# Epoch 24/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1501
# Epoch 25/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1664
# Epoch 26/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1089
# Epoch 27/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1279
# Epoch 28/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1051
# Epoch 29/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1151
# Epoch 30/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0979
# Epoch 31/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0759
# Epoch 32/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0735
# Epoch 33/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0679
# Epoch 34/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0610
# Epoch 35/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0588
# Epoch 36/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0548
# Epoch 37/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0513
# Epoch 38/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0490
# Epoch 39/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0462
# Epoch 40/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0453
# Epoch 41/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0431
# Epoch 42/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0418
# Epoch 43/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0402
# Epoch 44/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0386
# Epoch 45/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0372
# Epoch 46/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0359
# Epoch 47/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0344
# Epoch 48/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0338
# Epoch 49/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0322
# Epoch 50/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0314
# Epoch 51/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0304
# Epoch 52/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0297
# Epoch 53/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0286
# Epoch 54/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0278
# Epoch 55/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0270
# Epoch 56/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0262
# Epoch 57/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0252
# Epoch 58/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0241
# Epoch 59/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0229
# Epoch 60/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0239
# Epoch 61/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7345
# Epoch 62/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8750
# Epoch 63/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.3712
# Epoch 64/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1823
# Epoch 65/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1784
# Epoch 66/100
# 2/2 [==============================] - 6s 4s/step - loss: 0.1747
# Epoch 67/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1680
# Epoch 68/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1565
# Epoch 69/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1454
# Epoch 70/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.1325
# Epoch 71/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1170
# Epoch 72/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.1012
# Epoch 73/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0839
# Epoch 74/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.2855
# Epoch 75/100
# 2/2 [==============================] - 7s 4s/step - loss: 0.1099
# Epoch 76/100
# 2/2 [==============================] - 8s 4s/step - loss: 0.1387
# Epoch 77/100
# 2/2 [==============================] - 7s 4s/step - loss: 0.0891
# Epoch 78/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0989
# Epoch 79/100
# 2/2 [==============================] - 6s 2s/step - loss: 0.0827
# Epoch 80/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0832
# Epoch 81/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0752
# Epoch 82/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0695
# Epoch 83/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0632
# Epoch 84/100
# 2/2 [==============================] - 8s 3s/step - loss: 0.0592
# Epoch 85/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0538
# Epoch 86/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0492
# Epoch 87/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0452
# Epoch 88/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0411
# Epoch 89/100
# 2/2 [==============================] - 7s 3s/step - loss: 0.0378
# Epoch 90/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0357
# Epoch 91/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0354
# Epoch 92/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0333
# Epoch 93/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0317
# Epoch 94/100
# 2/2 [==============================] - 9s 5s/step - loss: 0.0306
# Epoch 95/100
# 2/2 [==============================] - 9s 4s/step - loss: 0.0289
# Epoch 96/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0275
# Epoch 97/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.0266
# Epoch 98/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0255
# Epoch 99/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0249
# Epoch 100/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0227

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])
# Out:
# 1/1 [==============================] - 0s 474ms/step

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 483ms/step
# 1/1 [==============================] - 1s 696ms/step

# %% [markdown]
# # Реализация FCN сети на основе блока ASPP
#
# Мы создадим еще еще одну сегментационную FCN модель на основе блока ASPP (Atrous Spatial Pyramid Pooling), который основан на дилатационных свёртках (Atrous Conv, Dilated Conv)
#
# <img src="img/aspp.jpg" width="1000">

# %% [markdown]
# ## Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения

# %%
img = imageio.v3.imread('img/me_256.png')
img = img.astype(np.float32) / 255.
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон

# %%
gt = imageio.v3.imread('img/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[...,None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать пайплайн для обучения, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x27a23467d60>, None)

# %% [markdown]
# ## Пайплайн обучения ASPP

# %% [markdown]
# ### Создание ASPP модели
# В этом примере мы будем создавать модель `ASPPNet` через собственный класс, наследованный от `tf.keras.Model`. Кроме того, будем использовать возможность модульного создания нейросетей. Сначала создадим отдельно модель для ASPP блока (блок, который содержит только дилатационные свёртки и применяется между энкодером и декодером), которая по сути будет являться самостоятельным слоем. А затем создадим финальную модель `ASPPNet`, в который `ASPPBlock` будет использоваться как слой между Энкодером и Декодером.
#
# В ASPP блоке (`ASPPBlock`) ко входному тензору параллельно применяются обычная свёртка 1x1 и несколько дилатационных свёрток. Затем все эти резульаты конкатенируются. Далее "перемешиваем" каналы полученного тензора с помощью еще одной свёртки 1x1.
#
# В финальной ASPP модели (`ASPPNet`) в качестве Энкодера будем использовать стандартные свёртки и пулинги. Далее в боттлнеке (в середине сети) применим слой ASPPBlock. А в Декодере будем использовать более простую архитектуру: меньше свёрток, повышение размерности с помощью двух билинейных интерполяций (`tf.image.resize`). Кроме того, в сети присутствуют две проброшенные связи.

# %%
class ASPPBlock(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=6, padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=12, padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=18, padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')

    def call(self, inp, is_training=False):
        out1 = self.conv1(inp)
        out2 = self.conv2(inp)
        out3 = self.conv3(inp)
        out4 = self.conv4(inp)
        out = tf.concat([out1, out2, out3, out4], axis=3)
        out = self.conv5(out)
        return out

class ASPPNet(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv7 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv8 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv9 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv10 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')

        self.conv11 = tf.keras.layers.Conv2D(48, (1, 1), padding='same', activation='relu')
        self.conv12 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv13 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv14 = tf.keras.layers.Conv2D(1, (1, 1), padding='same', activation=None)

        self.maxpool = tf.keras.layers.MaxPooling2D((2, 2), (2, 2), padding='same')

        self.aspp = ASPPBlock()

    def call(self, x):

        out = self.conv1(x)
        out = self.conv2(out)
        out = self.maxpool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.maxpool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out_enc_mid = out
        out = self.maxpool(out)
        out = self.conv7(out)
        out = self.conv8(out)
        out = self.maxpool(out)
        out = self.conv9(out)
        out = self.conv10(out)

        out = self.aspp(out)

        out = tf.image.resize(out, tf.shape(out_enc_mid)[1:3], tf.image.ResizeMethod.BILINEAR)

        out_enc_mid = self.conv11(out_enc_mid)

        out = tf.concat([out, out_enc_mid], axis=3)

        out = self.conv12(out)
        out = self.conv13(out)
        out = self.conv14(out)

        out = tf.image.resize(out, tf.shape(x)[1:3], tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out

model = ASPPNet()

# %% [markdown]
# ### Параметры обучения

# %%
NUM_EPOCHS = 100

# %% [markdown]
# ### Подготовка модели к обучению
# В качестве лосса используется бинарная кросс-энтропия (BinaryCrossentropy).
# В лоссе автоматически происходит суммирование по всем измерениям.

# %%
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer='adam', loss=loss)

# %% [markdown]
# ### Обучение модели

# %%
history = model.fit(train_x, train_y, batch_size=1, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.6621
# Epoch 2/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.0762
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.6700
# Epoch 4/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.6464
# Epoch 5/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.5298
# Epoch 6/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.4488
# Epoch 7/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.3489
# Epoch 8/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.2569
# Epoch 9/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2119
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1884
# Epoch 11/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1474
# Epoch 12/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.3224
# Epoch 13/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2173
# Epoch 14/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2129
# Epoch 15/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2059
# Epoch 16/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1949
# Epoch 17/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1743
# Epoch 18/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.2578
# Epoch 19/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1755
# Epoch 20/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1816
# Epoch 21/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1883
# Epoch 22/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1653
# Epoch 23/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1398
# Epoch 24/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1399
# Epoch 25/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1187
# Epoch 26/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1158
# Epoch 27/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1072
# Epoch 28/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.1001
# Epoch 29/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0968
# Epoch 30/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0924
# Epoch 31/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0894
# Epoch 32/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0872
# Epoch 33/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0852
# Epoch 34/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0838
# Epoch 35/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0822
# Epoch 36/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0805
# Epoch 37/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0789
# Epoch 38/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0771
# Epoch 39/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0764
# Epoch 40/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0750
# Epoch 41/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0746
# Epoch 42/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0742
# Epoch 43/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0754
# Epoch 44/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0724
# Epoch 45/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0699
# Epoch 46/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0696
# Epoch 47/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0686
# Epoch 48/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0663
# Epoch 49/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0644
# Epoch 50/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0649
# Epoch 51/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0624
# Epoch 52/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0634
# Epoch 53/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0588
# Epoch 54/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0546
# Epoch 55/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0553
# Epoch 56/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.2124
# Epoch 57/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1257
# Epoch 58/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1361
# Epoch 59/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.1361
# Epoch 60/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.1028
# Epoch 61/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0838
# Epoch 62/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0855
# Epoch 63/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.0873
# Epoch 64/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0796
# Epoch 65/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0737
# Epoch 66/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0718
# Epoch 67/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0670
# Epoch 68/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0658
# Epoch 69/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0605
# Epoch 70/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0578
# Epoch 71/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0553
# Epoch 72/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0512
# Epoch 73/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0449
# Epoch 74/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0400
# Epoch 75/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0358
# Epoch 76/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0365
# Epoch 77/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0359
# Epoch 78/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0529
# Epoch 79/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0448
# Epoch 80/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0365
# Epoch 81/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0387
# Epoch 82/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.0308
# Epoch 83/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0323
# Epoch 84/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0332
# Epoch 85/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0282
# Epoch 86/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0269
# Epoch 87/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0258
# Epoch 88/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0226
# Epoch 89/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0209
# Epoch 90/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0199
# Epoch 91/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0245
# Epoch 92/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0346
# Epoch 93/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.0590
# Epoch 94/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0416
# Epoch 95/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0371
# Epoch 96/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0362
# Epoch 97/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0337
# Epoch 98/100
# 2/2 [==============================] - 3s 1s/step - loss: 0.0324
# Epoch 99/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.0258
# Epoch 100/100
# 2/2 [==============================] - 3s 2s/step - loss: 0.0258

# %% [markdown]
# ### График зависимости лосса от эпохи

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ### Результат предсказания на входной картинке

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])
# Out:
# 1/1 [==============================] - 0s 454ms/step

# %% [markdown]
# ### Результат предсказания для всех картинок
# По предсказанию сети получается карта сегментации с помощью порога.
#
# Далее она отображается поверх исходной картинки.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 250ms/step
